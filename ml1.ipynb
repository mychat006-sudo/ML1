# %%
#Theory
"""
1. What is a parameter?

A parameter is a value inside a model that the model learns from data .

2. What is correlation?

Correlation tells how two variables are related to each other (if one changes, how the other changes).

 What does negative correlation mean?

If one value increases and the other decreases, it is called negative correlation (opposite movement).

3. Define Machine Learning. What are the main components in Machine Learning?

Machine Learning is teaching a computer to learn from data and make predictions.
Main components:
Data
Model
Training

4. How does loss value help in determining whether the model is good or not?
Loss shows how wrong the model is.
Low loss → good model
High loss → bad model

5. What are continuous and categorical variables?

Continuous → numbers (like age, salary)
Categorical → labels (like gender, city)


6. How do we handle categorical variables in Machine Learning? What are the common techniques?

We convert text into numbers:
One-hot encoding,Label encoding

7. What do you mean by training and testing a dataset?

Training → teach the model
Testing → check how well it learned

8. What is sklearn.preprocessing?

It is a module used to clean and prepare data (like scaling, encoding).

9. What is a Test set?

Test set is unseen data used to check model performance.

10. How do we split data for model fitting (training and testing) in Python?

We use train_test_split() from sklearn.

 How do you approach a Machine Learning problem?

Steps:
Understand problem
Clean data
Do EDA
Train model
Evaluate

12. Why do we have to perform EDA before fitting a model to the data?

EDA helps us understand data, find patterns, and fix problems before modeling.

13. What is correlation?

Correlation shows relationship between variables.

14. What does negative correlation mean?

One increases → other decreases.

15. How can you find correlation between variables in Python?

Using .corr() function in Pandas.

16. What is causation? Explain difference between correlation and causation with an example.

Correlation → variables are related
Causation → one causes the other

Example:
Ice cream sales ↑ and accidents ↑ → correlated
But ice cream doesn’t cause accidents (weather is reason)

17. What is an Optimizer? What are different types of optimizers? Explain each with an example.
Optimizer helps model learn by reducing error.
Types:

Gradient Descent
SGD
Adam

18. What is sklearn.linear_model?

It is a module used for linear models like Linear Regression.

19. What does model.fit() do? What arguments must be given?

It trains the model using data.
Arguments:

X (input data)
y (output/target)

20. What does model.predict() do? What arguments must be given?

It gives predictions.
Argument:
X (new data)

21. What are continuous and categorical variables?

Same as before:

Continuous → numeric
Categorical → labels

22. What is feature scaling? How does it help in Machine Learning?

Scaling means making values in same range.
Helps model learn faster and better.

23. How do we perform scaling in Python?
Using:
StandardScaler
MinMaxScaler

24. What is sklearn.preprocessing?

Used for data cleaning, scaling, encoding.

25. How do we split data for model fitting (training and testing) in Python?

Using train_test_split().

26. Explain data encoding?

Converting categorical data into numbers so model can understand.
"""
